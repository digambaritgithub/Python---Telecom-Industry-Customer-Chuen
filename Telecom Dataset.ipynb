# %% [markdown]
# Here, We Have analyzed the dataset of European Telecom Company.

# %% [markdown]
# This Telecom's Churn Dataset, consists of cleaned customer activity data (features). along with a churn label specifying
# whether a customer cancelled subscription.

# %%
We explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations
to ensure customer retention.

# %% [markdown]
# **Business Understanding Of A Telecom Industry Customer Churn**

# %% [markdown]
# Customer churn is a big problem in any industry and one of the most important concerns for the Telecom industry.
#
# The effect on the revenues of the companies, becomes of this customer is huge, especially in the telecom field. that's why these companies are seeking to develop a predict customer churn.

# %%
## import the required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the Dataset

data = pd.read_csv('D:\\Telecom\\Telecom dataset.csv')

# %%
data.head()                        # To show top 5 records of the dataset
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data.tail()                      # To show last 5 records of the dataset
# Out:
#      state  account length  area code phone number international plan  \
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total day calls  total day charge  ...  total eve calls  \
# 3328               77             26.55  ...              126
# ...

# %% [markdown]
# **shape**

# %%
data.shape                         # To show the number of Rows & Columns in the DataFrame
# Out:
# (3333, 21)

# %% [markdown]
# **Info()**

# %%
data.info()                       # To show basic informations of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %% [markdown]
# **describe()**

# %%
data.describe()  

# It gives the summary statistical of all numeric column. It check extreme outlier and large deviation etc.
# It show the count of non-null values in each column, and mean,std, minimum,maximum,
# 25th, 50th, 75th percentile values of each column.
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
data.nunique()           # To show the column names of the DataFrame
# Out:
# state                       51
# account length             212
# area code                    3
# phone number              3333
# international plan           2
# voice mail plan              2
# number vmail messages       46
# total day minutes         1667
# total day calls            119
# total day charge          1667
# total eve minutes         1611
# total eve calls            123
# total eve charge          1440
# total night minutes       1591
# total night calls          120
# total night charge         933
# total intl minutes         162
# total intl calls            21
# total intl charge          162
# customer service calls      10
# churn                        2
# dtype: int64

# %%
data.columns                # To show all the column names of the DataFrame
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %% [markdown]
# **dtypes**

# %%
data.dtypes              # To show data-type of each column
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %%
data.describe(include='object')   # It Gives the summary of all category columns

# It show the count of nan-values and unique values in each column, Top values with its accuracy in each column
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     382-4657                 no              no
# freq     106            1               3010            2411

# %% [markdown]
# **Cheking missing and Duplicate Values**

# %%
data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data.isna().sum()                # To show count of missing (null) values in each column
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %% [markdown]
# **isnull**

# %%
data.isnull().sum()                # Alternatively, To show the count of missing (null) values in each column
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %% [markdown]
# **duplicated()**

# %%
data[data.duplicated()]          # To show the dupocate record present in the DataFrame
                                 # In this dataframe, no duplicate record present
# Out:
# Empty DataFrame
# Columns: [state, account length, area code, phone number, international plan, voice mail plan, number vmail messages, total day minutes, total day calls, total day charge, total eve minutes, total eve calls, total eve charge, total night minutes, total night calls, total night charge, total intl minutes, total intl calls, total intl charge, customer service calls, churn]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# **drop_dupicates()**

# %%
data = data.drop_duplicates()     # To drop all the duplicates record from the DataFrame, and saving the updated Df

# %%
data
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# **1.Analyzing the 'Churn' variable**

# %%
data.head()           # To show Top 5 records of the DataFrame
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# **unique()**

# %%
data['churn'].unique()               # To show the unique values present in the column 'churn'
                                     # To show the dataset in the from of 1-D array
# Out:
# array([False,  True])

# %% [markdown]
# **value_counts()**

# %%
A = data['churn'].value_counts()        # To show the count of unique values of the column 'churn'

# %%
print(A)
# Out:
# False    2850
# True      483
# Name: churn, dtype: int64

# %%
str(483/3333*100) +"%"               # just to check the percentage of True (churned customer) from the dataset....
                                      # .... and showing the result in string format, afte adding % sign at the end
# Out:
# '14.491449144914492%'

# %%
type(A)                          # To check the type of variable 'A' ; it's a Series
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Donut Chart**

# %%
#Creating a Donut Chart for Churn vs Non-Churn Customer

plt.pie(A,labels=['Not Churned','Churned'], colors=['orange','lime'],startangle=50,shadow = True,radius = 2,
       explode = (0,0.2),autopct = '%1.2f%%',pctdistance = 0.75);
circle = plt.Circle((0,0),1,color='white')
c = plt.gcf()

c.gca().add_artist(circle)

plt.title("Churned vs Non-Churned Customers {DSL}")
plt.show()

# %% [markdown]
# **countplot**

# %%
# Countplot for chart vs Non-Chart Customer

sns.countplot(data['churn']);
# Out:
# C:\Users\Netizens\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Outcome-**

# %% [markdown]
# After analyzing the churn column, we notice that almost 15% customers have churned. now we will analyze other columns to find
# Out the reason for this churn

# %% [markdown]
# **2.Analyzing the 'State'Variable**

# %%
data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data.state.nunique()
# Out:
# 51

# %%
data.state.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
data.state.value_counts()           # To shw the occurance/count of all unique values of the column 'state'

# By default , it shows result in descending order
# To show the result in ascending order, we can write data.value_counts(ascending = True)
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: state, dtype: int64

# %% [markdown]
# **Countplot**

# %%
plt.figure(figsize=(20,7))

sns.countplot(data['state'])
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel('State',fontsize=20,color='Red')
plt.ylabel('Count',fontsize=20,color='Green')
plt.show()
# Out:
# C:\Users\Netizens\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
## Showing churn/not-churn state-wise

sns.set(style="whitegrid")                 # Using seaborn library, setting the background of the figure as "whitegrid"

plt.figure(figsize=(20,7))                # Setting the size of the figure as 20 x 7, using matplotlib library

sns.countplot(data.state,hue = data.churn)

plt.xlabel('States',fontsize = 18, color = "DarkBlue")
plt.ylabel("Count", fontsize = 18, color = "DarkOrange");
# Out:
# C:\Users\Netizens\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
a = data.groupby("state")['churn'].mean()*100

a.sort_values()
# Out:
# state
# HI     5.660377
# AK     5.769231
# AZ     6.250000
# VA     6.493506
# IA     6.818182
# LA     7.843137
# NE     8.196721
# IL     8.620690
# WI     8.974359
# RI     9.230769
# DC     9.259259
# TN     9.433962
# WV     9.433962
# NM     9.677419
# ND     9.677419
# AL    10.000000
# VT    10.958904
# MO    11.111111
# WY    11.688312
# ID    12.328767
# IN    12.676056
# FL    12.698413
# OH    12.820513
# SD    13.333333
# KY    13.559322
# CO    13.636364
# UT    13.888889
# OR    14.102564
# OK    14.754098
# DE    14.754098
# GA    14.814815
# NH    16.071429
# NC    16.176471
# CT    16.216216
# MA    16.923077
# PA    17.777778
# MN    17.857143
# NY    18.072289
# KS    18.571429
# AR    20.000000
# MT    20.588235
# ME    20.967742
# WA    21.212121
# NV    21.212121
# MS    21.538462
# MI    21.917808
# SC    23.333333
# MD    24.285714
# TX    25.000000
# NJ    26.470588
# CA    26.470588
# Name: churn, dtype: float64

# %% [markdown]
# **Linechart**

# %%
X = data.state.unique()
Y = data.groupby("state")["churn"].mean()

sns.set(style="darkgrid")

plt.rcParams['figure.figsize'] = (20,7)

plt.rcParams['lines.linestyle'] = '-'

plt.plot(X,Y, color="black", marker = '*', markersize = '10')

plt.title("State Churn Graph",fontsize = 25)
plt.xlabel("States",fontsize = 20)
plt.ylabel("Churn Rate",fontsize = 20);

# %%
data.groupby("state")["churn"].mean().sort_values(ascending = False).head(5)*100
# Out:
# state
# NJ    26.470588
# CA    26.470588
# TX    25.000000
# MD    24.285714
# SC    23.333333
# Name: churn, dtype: float64

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
# Calcualting State Vs Churn percentage

c = pd.crosstab(data.state,data.churn, margins = True)

c["Percentage_Churn"] = c[True]/(c['All']) * 100

print(c.head())
print(type(c))
# Out:
# churn  False  True  All  Percentage_Churn
# state
# AK        49     3   52          5.769231
# AL        72     8   80         10.000000
# AR        44    11   55         20.000000
# AZ        60     4   64          6.250000
# CA        25     9   34         26.470588
# <class 'pandas.core.frame.DataFrame'>

# %%
c.info()                        # To show the basic information of the DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, AK to All
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   False             52 non-null     int64
#  1   True              52 non-null     int64
#  2   All               52 non-null     int64
#  3   Percentage_Churn  52 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 2.0+ KB

# %% [markdown]
# **sort_values()**

# %%
c.sort_values(by = "Percentage_Churn",ascending = False).head()
# Out:
# churn  False  True  All  Percentage_Churn
# state
# CA        25     9   34         26.470588
# NJ        50    18   68         26.470588
# TX        54    18   72         25.000000
# MD        53    17   70         24.285714
# SC        46    14   60         23.333333

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# # 3. Analyzing the 'Area Code' Column**

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# **nunique()**

# %%
data["area code"].nunique()        # To check the total number of unique values present in the column 'area code'
# Out:
# 3

# %% [markdown]
# **unique()**

# %%
data['area code'].unique()
# Out:
# array([415, 408, 510], dtype=int64)

# %% [markdown]
# **value_counts()**

# %%
data['area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: area code, dtype: int64

# %%
data.groupby('area code')['churn'].mean() *100
# Out:
# area code
# 408    14.558473
# 415    14.259819
# 510    14.880952
# Name: churn, dtype: float64

# %% [markdown]
# **crosstab()**

# %%
# Claculating Area Code vs Churn Percentage

d = pd.crosstab(data['area code'], data['churn'], margins = True)

d['Churn Percentage'] = d[True]/(d['All'])*100

d
# Out:
# churn      False  True   All  Churn Percentage
# area code
# 408          716   122   838         14.558473
# 415         1419   236  1655         14.259819
# 510          715   125   840         14.880952
# All         2850   483  3333         14.491449

# %% [markdown]
# **Countplot()**

# %%
# Drawing  a  bar Graph to show Area cide wise churn

plt.figure(figsize = (14,5))

sns.countplot(x = 'area code', hue = 'churn', data = data);

# %% [markdown]
# ______________________________________________________________________________________________________

# %% [markdown]
# # 4.Analyzing the 'Account Length' column

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data['account length'].nunique()    # To show the total number of unique values presetn in the column 'Account length'
# Out:
# 212

# %% [markdown]
# **creating DataFrame**

# %%
# Creating two diffrent dataframes- one for 'churn  customer' & second for 'non-churned customer'

churn_data = data[data['churn']==True]
# creating a new dataframe "churn_data" in which we are considered all the records where churn is 'True'

not_churn_data = data[data['churn'] == False]
# Creating a nwe dataframe "not_churn", in which we are considering all the records where churn is 'False'

# %%
churn_data.head(2)
# Out:
#    state  account length  area code phone number international plan  \
# 10    IN              65        415     329-6603                 no
# 15    NY             161        415     351-7269                 no
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 10              no                      0              129.1              137
# 15              no                      0              332.9               67
#
#     total day charge  ...  total eve calls  total eve charge  \
# 10             21.95  ...               83             19.42
# 15             56.59  ...               97             27.01
#
#     total night minutes  total night calls  total night charge  \
# 10                208.8                111                9.40
# 15                160.6                128                7.23
#
#     total intl minutes  total intl calls  total intl charge  \
# 10                12.7                 6               3.43
# ...

# %%
not_churn_data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483 entries, 10 to 3323
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   483 non-null    object
#  1   account length          483 non-null    int64
#  2   area code               483 non-null    int64
#  3   phone number            483 non-null    object
#  4   international plan      483 non-null    object
#  5   voice mail plan         483 non-null    object
#  6   number vmail messages   483 non-null    int64
#  7   total day minutes       483 non-null    float64
#  8   total day calls         483 non-null    int64
#  9   total day charge        483 non-null    float64
#  10  total eve minutes       483 non-null    float64
#  11  total eve calls         483 non-null    int64
#  12  total eve charge        483 non-null    float64
#  13  total night minutes     483 non-null    float64
# ...

# %%
not_churn_data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data.shape
# Out:
# (3333, 21)

# %% [markdown]
# **Distribution Plot**

# %%
# Creating a Distribution plot for Account length column

sns.distplot(data['account length'],color='orange')
plt.xlabel("Account Length",fontsize = 15)
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\Netizens\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Comparing Account Length of 'churned' and 'not curned' customer, using displot

sns.distplot(data['account length'], color='grey',label = 'All')

sns.distplot(churn_data['account length'], hist = False, color='red',label = 'Churned')

sns.distplot(not_churn_data['account length'],hist = False,color = 'yellow',label = 'Not Churned')

plt.xlabel("Account Length",fontsize = 15)
plt.ylabel("Density",fontsize = 15)
plt.rcParams['figure.figsize'] = (15,7);
plt.show()
# Out:
# C:\Users\Netizens\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Netizens\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Analyze the 'International Plan' column

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# **unique()**

# %%
data['international plan'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %% [markdown]
# **value_counts()**

# %%
data['international plan'].value_counts()
# Out:
# no     3010
# yes     323
# Name: international plan, dtype: int64

# %%
# Creating a new dataframe 'yes_int_plan',.....
# .....containing the records of those churned customer who were having international plan

yes_int_plan = data[(data['international plan']== 'yes') & (data['churn'] == True)]
yes_int_plan
# Out:
#      state  account length  area code phone number international plan  \
# 41      MD             135        408     383-6029                yes
# 115     ME              36        510     363-1069                yes
# 144     VT             117        408     390-2390                yes
# 198     ME             131        510     353-7292                yes
# 214     FL              70        510     366-6345                yes
# ...    ...             ...        ...          ...                ...
# 3246    NC              77        408     334-6129                yes
# 3255    RI             138        510     411-6823                yes
# 3291    MI             119        510     335-7324                yes
# 3304    IL              71        510     330-7137                yes
# 3320    GA             122        510     411-5677                yes
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
no_int_plan = data[(data['international plan']== 'no') & (data['churn'] == True)]
no_int_plan
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 21      CO              77        408     393-7984                 no
# 33      AZ              12        408     360-1596                 no
# 48      ID             119        415     398-1294                 no
# ...    ...             ...        ...          ...                ...
# 3280    AR              76        408     345-3614                 no
# 3287    KS             170        415     404-5840                 no
# 3301    CA              84        415     417-1488                 no
# 3322    MD              62        408     409-1856                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
# We noticed that 323 customers were usig international plan, and 137 customers churned out of them
# means a chirn percentage of 42.4

137/323*100
# Out:
# 42.414860681114554

# %%
# We noticed that 3010 customer were not using international plan, and 346 customers churned out of them.
# means a churn percentage of 11.4

346/3010*100
# Out:
# 11.495016611295682

# %%
int_plan_data = pd.crosstab(data['international plan'],data['churn'],margins = True)
int_plan_data
# Out:
# churn               False  True   All
# international plan
# no                   2664   346  3010
# yes                   186   137   323
# All                  2850   483  3333

# %% [markdown]
# **creating new column**

# %%
# Creating new column 'churn percentage':- to show the churn percentage of the customer who were using intenational plan

int_plan_data['churn percentage'] = int_plan_data[True]/int_plan_data['All']*100

# %%
int_plan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, no to All
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   False             3 non-null      int64
#  1   True              3 non-null      int64
#  2   All               3 non-null      int64
#  3   churn percentage  3 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 120.0+ bytes

# %%
i = data['international plan'].value_counts()
i
# Out:
# no     3010
# yes     323
# Name: international plan, dtype: int64

# %% [markdown]
# **Donut Chart**

# %%
plt.pie(i,labels = ['No','Yes'],colors = ['yellow','cyan'],startangle=50, shadow = True, radius = 2,
       explode = (0,0.2),autopct = '%1.2f%%', pctdistance = 0.75);

circle = plt.Circle((0,0),1,color = 'white')
c = plt.gcf()

c.gca().add_artist(circle)

plt.title('International Plac (DSL)')
plt.rcParams['figure.figsize' ] = (5,7)
plt.show()

# %% [markdown]
# **Countplot**

# %%
sns.countplot(data['international plan'], hue = 'churn',data = data)
plt.rcParams['figure.figsize'] = (10,4)
plt.show()
# Out:
# C:\Users\Netizens\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 6.Analyzing the 'Voice Mail Plan' Column

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
sns.countplot(data['voice mail plan'],hue = 'churn',data = data, color = 'green')
plt.rcParams['figure.figsize'] = (10,5)
plt.show()
# Out:
# C:\Users\Netizens\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
vmplan = pd.crosstab(data['voice mail plan'],data['churn'],margins = True)

vmplan
# Out:
# churn            False  True   All
# voice mail plan
# no                2008   403  2411
# yes                842    80   922
# All               2850   483  3333

# %%
vmplan['churn percennt'] = vmplan[True]/ vmplan['All'] * 100
vmplan
# Out:
# churn            False  True   All  churn percennt
# voice mail plan
# no                2008   403  2411       16.715056
# yes                842    80   922        8.676790
# All               2850   483  3333       14.491449

# %%
v = data['voice mail plan'].value_counts()

v
# To show the occorance/count of all unique values of the column 'voice mail plan', and saving the output in variable 'v'
# Out:
# no     2411
# yes     922
# Name: voice mail plan, dtype: int64

# %% [markdown]
# **Donute Chart**

# %%
# Creating a Donut chart of customers count 'having voice mail plan' and 'not having voice mail plan'

plt.pie(v,labels = ['No','yes'], startangle = 90, shadow=True, radius = 1.5,explode = (0,0.1),autopct = '%1.2f%%')

circle = plt.Circle((0,0),0.8,color = 'white')
c = plt.gcf()

c.gca().add_artist(circle)

plt.title("voice mail plan DSL")

plt.show()
